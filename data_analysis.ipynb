# %% [markdown]
# # Exploratory Data Analysis
#
# #### In exploratory data analysis we try to find:
# - Missing Values
# - All The Numerical Variables
# - Distribution of the Numerical Variables
# - Categorical Variables
# - Cardinality of Categorical Variables
# - Outliers
# - Relationship between independent and dependent feature(SalePrice)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Shows all the columns in dataset
pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv("train.csv")

df.shape
# Out:
# (1460, 81)

# %%
sns.set_palette("husl", 9)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# #### Missing Values

# %%
# get features with nan values
features_with_nan = [features for features in df.columns if df[features].isnull().sum() >= 1]

# %%
# Count nan values per feature
for feature in features_with_nan:
    print(feature, np.round(df[feature].isnull().sum(), 4))
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
# persentage of missing values
for feature in features_with_nan:
    print(feature, np.round(df[feature].isnull().mean(), 4), "% missing values")
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# Electrical 0.0007 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values

# %% [markdown]
# #### Since there are many missing values, we need to find if there is any relationship between missing values and SalePrice

# %%
for feature in features_with_nan:
    data = df.copy()
    
    # put 1 where the value is missing and zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # calculate the mean of SalePrice where the information is missing or present
    data.groupby(feature)["SalePrice"].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# The relationship between Sale Price and missing values is visible. We will need to replace these missing values with something meaningful with the help of feature engineering

# %% [markdown]
# Some of the features like Id are not required and useless in prediction of the prices, we will remove them later.

# %%
print(f"Id of houses {len(df.Id)}")
# Out:
# Id of houses 1460

# %% [markdown]
# #### Numerical Features

# %%
# get all the features which are not object ('O')
numerical_features = [features for features in df.columns if df[features].dtypes != 'O']

print(f"Number of numerical variables: {len(numerical_features)}")
# Out:
# Number of numerical variables: 38

# %%
df[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# #### Temporal Variables(Eg: Datetime Variables)
# In the dataset we have 4 variables with the year. We have to extract information from the datetime variables like number of years or number of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold. We will perform it in Feature Engineering

# %%
# get the features with the year 

year_features = [features for features in numerical_features if 'Yr' in features or "Year" in features]

year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore year features

for feature in year_features:
    print(feature, df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# Analyze Temporal Datetime features
# Check if there is a relationship between Sale Price and the year the house is sold
plt.figure(figsize=(10,7))
df.groupby("YrSold")["SalePrice"].median().plot()
plt.xlabel("Year Sold")
plt.ylabel("Median House Price")
plt.title("House Price vs Year Sold")
# Out:
# Text(0.5, 1.0, 'House Price vs Year Sold')

# %%
# Compare the difference between Year Sold with all Temporal features and Sale Price

for feature in year_features:
    if feature != "YrSold":
        data = df.copy()
        
        # capture the difference between year sold and other year features in dataset
        data[feature] = data["YrSold"] - data[feature]
        
        plt.scatter(data[feature], data["SalePrice"])
        plt.xlabel(feature)
        plt.ylabel("Sale Price")
        plt.show()

# %%
# Numerical variables are usually of 2 types: continous and discrete 
# let's get the discrete features

discrete_features = [features for features in numerical_features if len(df[features].unique())<25 and features not in year_features+['Id']]

print(f"Number of discrete features: {len(discrete_features)}")
# Out:
# Number of discrete features: 17

# %%
df[discrete_features].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
# Let's find relationship between discrete features and Sale Price
for feature in discrete_features:
    data = df.copy()
    data.groupby(feature)["SalePrice"].median().plot.bar(color=sns.color_palette("pastel", 9))
    plt.xlabel(feature)
    plt.ylabel("Sale Price")
    plt.title(feature)
    plt.show()

# %% [markdown]
# There is a relationship between discrete features and sale price. In some cases the relationship is monotonic (exponential rise) in comparing Salee Price and Overall quality.

# %% [markdown]
# #### Continuous features

# %%
continuous_features = [features for features in numerical_features if features not in discrete_features+year_features+["Id"]]
print(f"Number of continuous features: {len(continuous_features)}")
# Out:
# Number of continuous features: 16

# %%
df[continuous_features].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0     208500
# ...

# %%
df[continuous_features].describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262   443.639726    46.549315
# std      24.284752    9981.264932   181.066207   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      59.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      69.000000    9478.500000     0.000000   383.500000     0.000000
# 75%      80.000000   11601.500000   166.000000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466  1515.463699
# std     441.866955   438.705324   386.587738   436.528436   525.480383
# ...

# %%
# Let's analyze continuous variables by creating histograms to understand the distribution

for feature in continuous_features:
    data = df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# Some of the continuous features have gaussian distribution (normal distribution), but many are skewed. We will try to normalize them.
# When solwing regression problem, we always have to convert non-gaussian distribution to gaussian or standard normal distribution, it will be helpful for linear model prediction.

# %%
# we will use logarithmic transformation

for feature in continuous_features:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data["SalePrice"] = np.log(data["SalePrice"])
        plt.scatter(data[feature], data["SalePrice"])
        plt.xlabel(feature)
        plt.ylabel("SalePrice")
        plt.title(feature)
        plt.show()

# %% [markdown]
# #### Outliers

# %%
for feature in continuous_features:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# There are a lot of outliers in continuous features

# %% [markdown]
# #### Categorical Features

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtypes == "O"]
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
df[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %% [markdown]
# We have to find out how many categories each categorical feature contains

# %%
for feature in categorical_features:
    data = df.copy()
    print(f"{feature} has {len(data[feature].unique())} categories")
# Out:
# MSZoning has 5 categories
# Street has 2 categories
# Alley has 3 categories
# LotShape has 4 categories
# LandContour has 4 categories
# Utilities has 2 categories
# LotConfig has 5 categories
# LandSlope has 3 categories
# Neighborhood has 25 categories
# Condition1 has 9 categories
# Condition2 has 8 categories
# BldgType has 5 categories
# HouseStyle has 8 categories
# RoofStyle has 6 categories
# RoofMatl has 8 categories
# Exterior1st has 15 categories
# Exterior2nd has 16 categories
# MasVnrType has 5 categories
# ExterQual has 4 categories
# ExterCond has 5 categories
# Foundation has 6 categories
# BsmtQual has 5 categories
# BsmtCond has 5 categories
# BsmtExposure has 5 categories
# BsmtFinType1 has 7 categories
# BsmtFinType2 has 7 categories
# Heating has 6 categories
# HeatingQC has 5 categories
# CentralAir has 2 categories
# Electrical has 6 categories
# KitchenQual has 4 categories
# Functional has 7 categories
# FireplaceQu has 6 categories
# ...

# %% [markdown]
# We need to find out if there is a relationship between categorical features and dependent feature

# %%
for feature in categorical_features:
    data = df.copy()
    data.groupby(feature)["SalePrice"].median().plot.bar(color=sns.color_palette("pastel", 9))
    plt.xlabel(feature)
    plt.ylabel("SalePrice")
    plt.title(feature)
    plt.show()
